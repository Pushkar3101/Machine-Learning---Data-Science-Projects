# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train = pd.read_excel('Data_Train.xlsx')
test = pd.read_excel('Data_Test.xlsx')

# %%
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
train.tail()
# Out:
#                           Name   Location  Year  Kilometers_Driven Fuel_Type  \
# 6014          Maruti Swift VDI      Delhi  2014              27365    Diesel
# 6015  Hyundai Xcent 1.1 CRDi S     Jaipur  2015             100000    Diesel
# 6016     Mahindra Xylo D4 BSIV     Jaipur  2012              55000    Diesel
# 6017        Maruti Wagon R VXI    Kolkata  2013              46000    Petrol
# 6018     Chevrolet Beat Diesel  Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type     Mileage   Engine     Power  Seats  New_Price  \
# 6014       Manual      First   28.4 kmpl  1248 CC    74 bhp    5.0  7.88 Lakh
# 6015       Manual      First   24.4 kmpl  1120 CC    71 bhp    5.0        NaN
# 6016       Manual     Second   14.0 kmpl  2498 CC   112 bhp    8.0        NaN
# 6017       Manual      First   18.9 kmpl   998 CC  67.1 bhp    5.0        NaN
# 6018       Manual      First  25.44 kmpl   936 CC  57.6 bhp    5.0        NaN
#
#       Price
# 6014   4.75
# ...

# %%
test.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# ...

# %%
train.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
len(train)
# Out:
# 6019

# %%
train.describe
# Out:
# <bound method NDFrame.describe of                                                   Name    Location  Year  \
# 0                               Maruti Wagon R LXI CNG      Mumbai  2010
# 1                     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                         Honda Jazz V     Chennai  2011
# 3                                    Maruti Ertiga VDI     Chennai  2012
# 4                      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                               Nissan Micra Diesel XV      Jaipur  2013
# 7                    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                       Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                    Maruti Ciaz Zeta       Kochi  2018
# ...

# %%
len(train.Name.unique())
# Out:
# 1876

# %%
from sklearn import preprocessing
label = preprocessing.LabelEncoder()

# %%
col = ['Name','Location','Fuel_Type','Transmission','Owner_Type']
for item in col:
    train[item] = label.fit_transform(train[item])
    test[item] = label.fit_transform(test[item])

# %%
train.head(10)
# Out:
#    Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0  1200         9  2010              72000          0             1
# 1   512        10  2015              41000          1             1
# 2   486         2  2011              46000          4             1
# 3  1059         2  2012              87000          1             1
# 4    23         3  2013              40670          1             0
# 5   530         5  2012              75000          3             1
# 6  1378         6  2013              86999          1             1
# 7  1778         9  2016              36000          1             0
# 8  1847        10  2013              64430          1             1
# 9  1582         2  2012              65932          1             1
#
#    Owner_Type     Mileage   Engine      Power  Seats  New_Price  Price
# 0           0  26.6 km/kg   998 CC  58.16 bhp    5.0        NaN   1.75
# 1           0  19.67 kmpl  1582 CC  126.2 bhp    5.0        NaN  12.50
# ...

# %%
train.isnull().any()
# Out:
# Name                 False
# Location             False
# Year                 False
# Kilometers_Driven    False
# Fuel_Type            False
# Transmission         False
# Owner_Type           False
# Mileage               True
# Engine                True
# Power                 True
# Seats                 True
# New_Price             True
# Price                False
# dtype: bool

# %%
test.isnull().any()
# Out:
# Name                 False
# Location             False
# Year                 False
# Kilometers_Driven    False
# Fuel_Type            False
# Transmission         False
# Owner_Type           False
# Mileage              False
# Engine                True
# Power                 True
# Seats                 True
# New_Price             True
# dtype: bool

# %%
train.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
train =train.drop('New_Price',1)
test = test.drop('New_Price',1)
train.head()
# Out:
#    Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0  1200         9  2010              72000          0             1
# 1   512        10  2015              41000          1             1
# 2   486         2  2011              46000          4             1
# 3  1059         2  2012              87000          1             1
# 4    23         3  2013              40670          1             0
#
#    Owner_Type     Mileage   Engine      Power  Seats  Price
# 0           0  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75
# 1           0  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50
# 2           0   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50
# 3           0  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00
# 4           2   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74

# %%
df_nan = train[train.isna().any(axis=1)]
df_nan
# Out:
#       Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 194    417         0  2007              60006          4             1
# 208   1120         8  2010              42001          4             1
# 229    324         1  2015              70436          1             1
# 733   1120         2  2006              97800          4             1
# 749    814         9  2008              55001          1             0
# 1294   410         4  2009              55005          4             1
# 1327  1121         5  2015              50295          4             1
# 1385   417        10  2004             115000          4             1
# 1460   822         3  2008              69078          4             1
# 1917   414         6  2005              88000          4             1
# 2074  1118        10  2011              24255          4             1
# 2096   592         3  2004              52146          4             1
# ...

# %%
len(df_nan)
# Out:
# 44

# %%
train['Mileage'] = train.Mileage.str.replace("[^\d\.]",'')

# %%
train['Mileage']
# Out:
# 0        26.6
# 1       19.67
# 2        18.2
# 3       20.77
# 4        15.2
# 5        21.1
# 6       23.08
# 7       11.36
# 8       20.54
# 9        22.3
# 10      21.56
# 11       16.8
# 12       25.2
# 13       12.7
# 14        0.0
# 15       13.5
# 16       25.8
# 17       28.4
# 18      20.45
# 19      14.84
# 20      22.69
# 21      23.65
# 22      13.53
# 23       18.5
# 24       14.4
# 25       16.8
# 26      23.08
# 27      20.92
# 28       17.5
# 29       12.8
#         ...
# 5989    18.25
# 5990    13.93
# 5991     22.9
# 5992     13.7
# 5993     16.3
# 5994     17.0
# 5995    19.87
# 5996    16.36
# 5997     26.2
# 5998    17.24
# 5999    17.57
# 6000     18.5
# 6001    17.68
# 6002    16.09
# 6003     23.1
# 6004     15.3
# 6005     24.3
# 6006      8.7
# 6007     19.3
# 6008    17.85
# 6009    19.16
# 6010     18.5
# 6011      0.0
# 6012     12.8
# 6013     25.8
# 6014     28.4
# 6015     24.4
# 6016     14.0
# 6017     18.9
# 6018    25.44
# ...

# %%
train['Engine'] = train.Engine.str.replace("[^\d\.]",'')
train['Power'] = train.Power.str.replace("[^\d\.]",'')

# %%
test['Mileage'] = test.Mileage.str.replace("[^\d\.]",'')
test['Engine'] = test.Engine.str.replace("[^\d\.]",'')
test['Power'] = test.Power.str.replace("[^\d\.]",'')

# %%
train.head()
# Out:
#    Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0  1200         9  2010              72000          0             1
# 1   512        10  2015              41000          1             1
# 2   486         2  2011              46000          4             1
# 3  1059         2  2012              87000          1             1
# 4    23         3  2013              40670          1             0
#
#    Owner_Type Mileage Engine  Power  Seats  Price
# 0           0    26.6    998  58.16    5.0   1.75
# 1           0   19.67   1582  126.2    5.0  12.50
# 2           0    18.2   1199   88.7    5.0   4.50
# 3           0   20.77   1248  88.76    7.0   6.00
# 4           2    15.2   1968  140.8    5.0  17.74

# %%
train['Mileage'] = train['Mileage'].astype(float)
test['Mileage'] = test['Mileage'].astype(float)

# %%
train['Engine'] = train['Engine'].astype(float)
test['Engine'] = test['Engine'].astype(float)

# %%
type(train['Power'][0])
# Out:
# str

# %%
train['Power'] = pd.to_numeric(train['Power'], errors='coerce')
test['Power'] = pd.to_numeric(test['Power'], errors='coerce')

# %%
train.mean()
# Out:
# Name                   915.975577
# Location                 5.619704
# Year                  2013.358199
# Kilometers_Driven    58738.380296
# Fuel_Type                2.363017
# Transmission             0.714238
# Owner_Type               0.379465
# Mileage                 18.134961
# Engine                1621.276450
# Power                  113.253050
# Seats                    5.278735
# Price                    9.479468
# dtype: float64

# %%
train = train.fillna(train.mean())
test = test.fillna(test.mean())

# %%
train.isnull().any()
# Out:
# Name                 False
# Location             False
# Year                 False
# Kilometers_Driven    False
# Fuel_Type            False
# Transmission         False
# Owner_Type           False
# Mileage              False
# Engine               False
# Power                False
# Seats                False
# Price                False
# dtype: bool

# %%
train['Mileage'] = train['Mileage'].replace(0,train['Mileage'].mean())
test['Mileage'] = test['Mileage'].replace(0,test['Mileage'].mean())

# %%
train.loc[194]
# Out:
# Name                   417.000000
# Location                 0.000000
# Year                  2007.000000
# Kilometers_Driven    60006.000000
# Fuel_Type                4.000000
# Transmission             1.000000
# Owner_Type               0.000000
# Mileage                 18.134961
# Engine                1621.276450
# Power                  113.253050
# Seats                    5.278735
# Price                    2.950000
# Name: 194, dtype: float64

# %%
train.head()
# Out:
#    Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0  1200         9  2010              72000          0             1
# 1   512        10  2015              41000          1             1
# 2   486         2  2011              46000          4             1
# 3  1059         2  2012              87000          1             1
# 4    23         3  2013              40670          1             0
#
#    Owner_Type  Mileage  Engine   Power  Seats  Price
# 0           0    26.60   998.0   58.16    5.0   1.75
# 1           0    19.67  1582.0  126.20    5.0  12.50
# 2           0    18.20  1199.0   88.70    5.0   4.50
# 3           0    20.77  1248.0   88.76    7.0   6.00
# 4           2    15.20  1968.0  140.80    5.0  17.74

# %%
test.head()
# Out:
#    Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0   413         4  2014              40929          0             1
# 1   408         3  2013              54493          3             1
# 2   723         9  2017              34000          1             1
# 3   689         5  2012             139000          1             1
# 4   333         9  2014              29000          3             1
#
#    Owner_Type  Mileage  Engine      Power  Seats
# 0           0    32.26   998.0   58.20000    4.0
# 1           2    24.70   796.0   47.30000    5.0
# 2           0    13.68  2393.0  147.80000    7.0
# 3           0    23.59  1364.0  110.38042    5.0
# 4           0    18.50  1197.0   82.85000    5.0

# %%
import seaborn as sns

plt.style.use('fivethirtyeight')
sns.set_style("white")

corr = train.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
data, ax = plt.subplots(figsize=(8, 8))
plt.title('Car Feature Correlation')

# Generate a custom diverging colormap
cmap = sns.diverging_palette(260, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, vmax=1.2, square='square', cmap=cmap, mask=mask, 
            ax=ax,annot=True, fmt='.2g',linewidths=2)

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# %%
col= ['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type','Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats']
X_train = train[col]
y_train = train['Price']

# %%
X_train.head()
# Out:
#    Name  Location  Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0  1200         9  2010              72000          0             1
# 1   512        10  2015              41000          1             1
# 2   486         2  2011              46000          4             1
# 3  1059         2  2012              87000          1             1
# 4    23         3  2013              40670          1             0
#
#    Owner_Type  Mileage  Engine   Power  Seats
# 0           0    26.60   998.0   58.16    5.0
# 1           0    19.67  1582.0  126.20    5.0
# 2           0    18.20  1199.0   88.70    5.0
# 3           0    20.77  1248.0   88.76    7.0
# 4           2    15.20  1968.0  140.80    5.0

# %%
X_train = scale.fit_transform(X_train)
X_test = scale.fit_transform(test)
# Out:
# C:\Users\pushkar\Anaconda3\anaconda_\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\pushkar\Anaconda3\anaconda_\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\pushkar\Anaconda3\anaconda_\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\pushkar\Anaconda3\anaconda_\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
y_test = pd.read_excel('Sample_submission.xlsx')

# %%
y_test.head()
# Out:
#    Price
# 0  55.02
# 1  56.46
# 2  34.61
# 3  16.89
# 4  50.48

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** (1/2)
print(rmse)
# Out:
# 52.03843065177793

# %%
from sklearn import neighbors
from math import sqrt
rmse_val = [] 
for K in range(10):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(X_train, y_train) 
    pred=model.predict(X_test) 
    error = sqrt(mean_squared_error(y_test,pred)) 
    rmse_val.append(error) 
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 52.476397462866224
# RMSE value for k=  2 is: 52.360395516638654
# RMSE value for k=  3 is: 52.245199640592084
# RMSE value for k=  4 is: 52.21667128886389
# RMSE value for k=  5 is: 52.197545824900864
# RMSE value for k=  6 is: 52.21506494753874
# RMSE value for k=  7 is: 52.21391181377592
# RMSE value for k=  8 is: 52.21560529682314
# RMSE value for k=  9 is: 52.192557786274534
# RMSE value for k=  10 is: 52.20126477162884

# %%
model = neighbors.KNeighborsRegressor(n_neighbors = 5)
model.fit(X_train, y_train) 
y_pred=model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** (1/2)
print(rmse)
# Out:
# 52.197545824900864

# %%
from sklearn.ensemble import GradientBoostingRegressor
# get an instance of the model, using ‘ls’ : least squares regression as a loss function and the default learning rate which 0.1
gbr = GradientBoostingRegressor(loss ='ls', max_depth=6)
# fit the training data
gbr.fit (X_train, y_train)
# get the predicted values from the test set
y_pred = gbr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** (1/2)
print(rmse)
submission = pd.read_excel('Sample_submission.xlsx')
submission['Price'] = y_pred
submission.to_excel('submit_file.xlsx',index=False)
# Out:
# 51.67993564491226

# %%
from sklearn.linear_model import BayesianRidge
model = BayesianRidge()
model.fit(X_train, y_train) 
y_pred=model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** (1/2)
print(rmse)
# Out:
# 52.03830793932528
